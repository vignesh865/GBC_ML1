# %% [markdown]
# # Task: Covid-19 Data Analysis
# ### This notebook is used to understand the comprehension of Data Analysis techniques using Pandas library.

# %% [markdown]
# ### Data Source:
# https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports
#
# ### File naming convention
#
# MM-DD-YYYY.csv in UTC.
#
# ### Field description
#
# - Province_State: China - province name; US/Canada/Australia/ - city name, state/province name; Others - name of the event (e.g., "Diamond Princess" cruise ship); other countries - blank.
#
# - Country_Region: country/region name conforming to WHO (will be updated).
#
# - Last_Update: MM/DD/YYYY HH:mm (24 hour format, in UTC).
#
# - Confirmed: the number of confirmed cases. For Hubei Province: from Feb 13 (GMT +8), we report both clinically diagnosed and lab-confirmed cases. For lab-confirmed cases only (Before Feb 17), please refer to who_covid_19_situation_reports. For Italy, diagnosis standard might be changed since Feb 27 to "slow the growth of new case numbers." (Source)
#
# - Deaths: the number of deaths.
#
# - Recovered: the number of recovered cases.

# %%
import pandas as pd

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Read the dataset

# %%
covid_df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv")
covid_df
# Out:
#       FIPS Admin2    Province_State  Country_Region          Last_Update  \
# 0      NaN    NaN               NaN     Afghanistan  2021-01-02 05:22:33
# 1      NaN    NaN               NaN         Albania  2021-01-02 05:22:33
# 2      NaN    NaN               NaN         Algeria  2021-01-02 05:22:33
# 3      NaN    NaN               NaN         Andorra  2021-01-02 05:22:33
# 4      NaN    NaN               NaN          Angola  2021-01-02 05:22:33
# ...    ...    ...               ...             ...                  ...
# 4006   NaN    NaN           Unknown         Ukraine  2021-01-02 05:22:33
# 4007   NaN    NaN               NaN           Nauru  2021-01-02 05:22:33
# 4008   NaN    NaN              Niue     New Zealand  2021-01-02 05:22:33
# 4009   NaN    NaN               NaN          Tuvalu  2021-01-02 05:22:33
# 4010   NaN    NaN  Pitcairn Islands  United Kingdom  2021-01-02 05:22:33
#
#            Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0     33.93911   67.709953      52513    2201      41727    8585
# 1     41.15330   20.168300      58316    1181      33634   23501
# 2     28.03390    1.659600      99897    2762      67395   29740
# 3     42.50630    1.521800       8117      84       7463     570
# 4    -11.20270   17.873900      17568     405      11146    6017
# ...        ...         ...        ...     ...        ...     ...
# 4006       NaN         NaN          0       0          0       0
# 4007  -0.52280  166.931500          0       0          0       0
# 4008 -19.05440 -169.867200          0       0          0       0
# 4009  -7.10950  177.649300          0       0          0       0
# 4010 -24.37680 -128.324200          0       0          0       0
#
#                           Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0                          Afghanistan     134.896578             4.191343
# 1                              Albania    2026.409062             2.025173
# 2                              Algeria     227.809861             2.764848
# 3                              Andorra   10505.403482             1.034865
# 4                               Angola      53.452981             2.305328
# ...                                ...            ...                  ...
# 4006                  Unknown, Ukraine       0.000000             0.000000
# 4007                             Nauru       0.000000             0.000000
# 4008                 Niue, New Zealand       0.000000             0.000000
# 4009                            Tuvalu       0.000000             0.000000
# 4010  Pitcairn Islands, United Kingdom       0.000000             0.000000
#
# [4011 rows x 14 columns]

# %% [markdown]
# #### Display the top 5 rows in the data

# %%
covid_df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953      52513    2201      41727    8585  Afghanistan
# 1  20.168300      58316    1181      33634   23501      Albania
# 2   1.659600      99897    2762      67395   29740      Algeria
# 3   1.521800       8117      84       7463     570      Andorra
# 4  17.873900      17568     405      11146    6017       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     134.896578             4.191343
# 1    2026.409062             2.025173
# 2     227.809861             2.764848
# 3   10505.403482             1.034865
# 4      53.452981             2.305328

# %% [markdown]
# #### Show the information of the dataset

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4011 entries, 0 to 4010
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3265 non-null   float64
#  1   Admin2               3270 non-null   object
#  2   Province_State       3833 non-null   object
#  3   Country_Region       4011 non-null   object
#  4   Last_Update          4011 non-null   object
#  5   Lat                  3922 non-null   float64
#  6   Long_                3922 non-null   float64
#  7   Confirmed            4011 non-null   int64
#  8   Deaths               4011 non-null   int64
#  9   Recovered            4011 non-null   int64
#  10  Active               4011 non-null   int64
#  11  Combined_Key         4011 non-null   object
#  12  Incident_Rate        3922 non-null   float64
#  13  Case_Fatality_Ratio  3963 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 438.8+ KB

# %% [markdown]
# #### Show the sum of missing values of features in the dataset

# %%
covid_df.isna().sum()
# Out:
# FIPS                   746
# Admin2                 741
# Province_State         178
# Country_Region           0
# Last_Update              0
# Lat                     89
# Long_                   89
# Confirmed                0
# Deaths                   0
# Recovered                0
# Active                   0
# Combined_Key             0
# Incident_Rate           89
# Case_Fatality_Ratio     48
# dtype: int64

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Show the number of Confirmed cases by Country

# %%
covid_df[["Country_Region", "Confirmed"]].groupby("Country_Region",  as_index = False).sum()
# Out:
#            Country_Region  Confirmed
# 0             Afghanistan      52513
# 1                 Albania      58316
# 2                 Algeria      99897
# 3                 Andorra       8117
# 4                  Angola      17568
# ..                    ...        ...
# 195    West Bank and Gaza     139223
# 196  Winter Olympics 2022          0
# 197                 Yemen       2101
# 198                Zambia      20997
# 199              Zimbabwe      14084
#
# [200 rows x 2 columns]

# %% [markdown]
# #### Show the number of Deaths by Country

# %%
covid_df[["Country_Region", "Deaths"]].groupby("Country_Region",  as_index = False).sum()
# Out:
#            Country_Region  Deaths
# 0             Afghanistan    2201
# 1                 Albania    1181
# 2                 Algeria    2762
# 3                 Andorra      84
# 4                  Angola     405
# ..                    ...     ...
# 195    West Bank and Gaza    1418
# 196  Winter Olympics 2022       0
# 197                 Yemen     610
# 198                Zambia     390
# 199              Zimbabwe     369
#
# [200 rows x 2 columns]

# %% [markdown]
# #### Show the number of Recovered cases by Country

# %%
covid_df[["Country_Region", "Recovered"]].groupby("Country_Region",  as_index = False).sum()
# Out:
#            Country_Region  Recovered
# 0             Afghanistan      41727
# 1                 Albania      33634
# 2                 Algeria      67395
# 3                 Andorra       7463
# 4                  Angola      11146
# ..                    ...        ...
# 195    West Bank and Gaza     118926
# 196  Winter Olympics 2022          0
# 197                 Yemen       1396
# 198                Zambia      18773
# 199              Zimbabwe      11347
#
# [200 rows x 2 columns]

# %% [markdown]
# #### Show the number of Active Cases by Country

# %%
covid_df[["Country_Region", "Active"]].groupby("Country_Region",  as_index = False).sum()
# Out:
#            Country_Region  Active
# 0             Afghanistan    8585
# 1                 Albania   23501
# 2                 Algeria   29740
# 3                 Andorra     570
# 4                  Angola    6017
# ..                    ...     ...
# 195    West Bank and Gaza   18879
# 196  Winter Olympics 2022       0
# 197                 Yemen      95
# 198                Zambia    1834
# 199              Zimbabwe    2368
#
# [200 rows x 2 columns]

# %% [markdown]
# #### Show the latest number of Confirmed, Deaths, Recovered and Active cases Country-wise

# %%
covid_df["Last_Update"] = pd.to_datetime(covid_df.Last_Update)

# %% [markdown]
# Date and time is same for all the record in this dataframe. So, there is no context of latest here. We will consider last record as latest.

# %%
covid_df[["Country_Region", "Last_Update",
          "Active", "Confirmed", 
          "Deaths", "Recovered"]].groupby("Country_Region", 
                                          as_index = False).last()
# Out:
#            Country_Region          Last_Update  Active  Confirmed  Deaths  \
# 0             Afghanistan  2021-01-02 05:22:33    8585      52513    2201
# 1                 Albania  2021-01-02 05:22:33   23501      58316    1181
# 2                 Algeria  2021-01-02 05:22:33   29740      99897    2762
# 3                 Andorra  2021-01-02 05:22:33     570       8117      84
# 4                  Angola  2021-01-02 05:22:33    6017      17568     405
# ..                    ...                  ...     ...        ...     ...
# 195    West Bank and Gaza  2021-01-02 05:22:33   18879     139223    1418
# 196  Winter Olympics 2022  2021-01-02 05:22:33       0          0       0
# 197                 Yemen  2021-01-02 05:22:33      95       2101     610
# 198                Zambia  2021-01-02 05:22:33    1834      20997     390
# 199              Zimbabwe  2021-01-02 05:22:33    2368      14084     369
#
#      Recovered
# 0        41727
# 1        33634
# 2        67395
# 3         7463
# 4        11146
# ..         ...
# 195     118926
# 196          0
# 197       1396
# 198      18773
# 199      11347
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### Show the countries with no recovered cases

# %%
no_recovered_df = covid_df[["Country_Region", "Recovered"]].groupby("Country_Region", as_index = False).sum()
no_recovered_df[no_recovered_df["Recovered"] == 0]
# Out:
#            Country_Region  Recovered
# 5              Antarctica          0
# 17                Belgium          0
# 92               Kiribati          0
# 93           Korea, North          0
# 125                 Nauru          0
# 136                 Palau          0
# 156                Serbia          0
# 169  Summer Olympics 2020          0
# 171                Sweden          0
# 180                 Tonga          0
# 184                Tuvalu          0
# 185                    US          0
# 196  Winter Olympics 2022          0

# %% [markdown]
# #### Show the countries with no confirmed cases

# %%
no_confirmed_df = covid_df[["Country_Region", "Confirmed"]].groupby("Country_Region", as_index = False).sum()
no_confirmed_df[no_confirmed_df["Confirmed"] == 0]
# Out:
#            Country_Region  Confirmed
# 5              Antarctica          0
# 92               Kiribati          0
# 93           Korea, North          0
# 125                 Nauru          0
# 136                 Palau          0
# 169  Summer Olympics 2020          0
# 180                 Tonga          0
# 184                Tuvalu          0
# 196  Winter Olympics 2022          0

# %% [markdown]
# #### Show the countries with no deaths

# %%
no_deaths_df = covid_df[["Country_Region", "Deaths"]].groupby("Country_Region", as_index = False).sum()
no_deaths_df[no_deaths_df["Deaths"] == 0]
# Out:
#                        Country_Region  Deaths
# 5                          Antarctica       0
# 20                             Bhutan       0
# 31                           Cambodia       0
# 51                           Dominica       0
# 70                            Grenada       0
# 76                           Holy See       0
# 92                           Kiribati       0
# 93                       Korea, North       0
# 98                               Laos       0
# 114                  Marshall Islands       0
# 125                             Nauru       0
# 136                             Palau       0
# 148             Saint Kitts and Nevis       0
# 150  Saint Vincent and the Grenadines       0
# 151                             Samoa       0
# 157                        Seychelles       0
# 162                   Solomon Islands       0
# 169              Summer Olympics 2020       0
# 178                       Timor-Leste       0
# 180                             Tonga       0
# 184                            Tuvalu       0
# 192                           Vanuatu       0
# 196              Winter Olympics 2022       0

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### Show the Top 10 countries with Confirmed cases

# %%
covid_df[["Country_Region", "Confirmed", "Deaths", "Recovered"]].groupby("Country_Region",  as_index = False).sum().sort_values("Confirmed", ascending=False).head(10)
# Out:
#      Country_Region  Confirmed  Deaths  Recovered
# 185              US   20397401  352844          0
# 80            India   10305788  149218    9929568
# 24           Brazil    7703971  195541    6855372
# 146          Russia    3153960   56798    2553467
# 63           France    2697014   64891     200822
# 189  United Kingdom    2549671   95917       5682
# 183          Turkey    2220855   21093    2114760
# 86            Italy    2129376   74621    1479988
# 166           Spain    1928265   50837     150376
# 67          Germany    1721839   33071    1388744

# %% [markdown]
# #### Show the Top 10 Countries with Active cases

# %%
covid_df[["Country_Region", "Confirmed", "Deaths", "Recovered", "Active"]].groupby("Country_Region",  as_index = False).sum().sort_values("Active", ascending=False).head(10)
# Out:
#      Country_Region  Confirmed  Deaths  Recovered    Active
# 185              US   20397401  352844          0  19978335
# 189  United Kingdom    2549671   95917       5682   2469774
# 63           France    2697014   64891     200822   2431301
# 166           Spain    1928265   50837     150376   1727052
# 117          Mexico    1437185  126507    1083768   1310678
# 140            Peru    1015137   93231     951318    921906
# 127     Netherlands     816616   11624       9651    795341
# 24           Brazil    7703971  195541    6855372    649795
# 17          Belgium     648289   19581          0    637588
# 86            Italy    2129376   74621    1479988    574767

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### Plot Country-wise Total deaths, confirmed, recovered and active casaes where total deaths have exceeded 50,000

# %%
import plotly.graph_objects as go

# %%
grouped_df1 = covid_df[["Country_Region", "Confirmed", "Active", "Recovered", "Deaths"]].groupby("Country_Region", as_index = False).sum()
grouped_df1 = grouped_df1[grouped_df1["Deaths"] >= 50000]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=grouped_df1["Country_Region"], y=grouped_df1["Confirmed"],
                    mode='lines', name='Confirmed'))
fig.add_trace(go.Scatter(x=grouped_df1["Country_Region"], y=grouped_df1["Deaths"],
                    mode='lines', name='Deaths'))
fig.add_trace(go.Scatter(x=grouped_df1["Country_Region"], y=grouped_df1["Recovered"],
                    mode='lines', name='Recovered'))
fig.add_trace(go.Scatter(x=grouped_df1["Country_Region"], y=grouped_df1["Active"],
                    mode='lines', name='Active'))

fig.show()
# Out:
# <div>                            <div id="50a960bf-a89f-4481-8d09-017e9519cd12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50a960bf-a89f-4481-8d09-017e9519cd12")) {                    Plotly.newPlot(                        "50a960bf-a89f-4481-8d09-017e9519cd12",                        [{"mode":"lines","name":"Confirmed","x":["Brazil","France","India","Iran","Italy","Mexico","Peru","Russia","Spain","US","United Kingdom"],"y":[7703971,2697014,10305788,1231429,2129376,1437185,1015137,3153960,1928265,20397401,2549671],"type":"scatter"},{"mode":"lines","name":"Deaths","x":["Brazil","France","India","Iran","Italy","Mexico","Peru","Russia","Spain","US","United Kingdom"],"y":[195541,64891,149218,55337,74621,126507,93231,56798,50837,352844,95917],"type":"scatter"},{"mode":"lines","name":"Recovered","x":["Brazil","France","India","Iran","Italy","Mexico","Peru","Russia","Spain","US","United Kingdom"],"y":[6855372,200822,9929568,995570,1479988,1083768,951318,2553467,150376,0,5682],"type":"scatter"},{"mode":"lines","name":"Active","x":["Brazil","France","India","Iran","Italy","Mexico","Peru","Russia","Spain","US","United Kingdom"],"y":[649795,2431301,273109,180522,574767,1310678,921906,543695,1727052,19978335,2469774],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}] ...

# %% [markdown]
# ### Question 6

# %% [markdown]
# ### Plot Province/State wise Deaths in USA

# %%
import plotly.express as px

# %%
covid_data= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-09-2021.csv')

# %%
covid_data.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')

# %%
usa_data = covid_data[covid_data["Country_Region"] == "US"]

# %%
all_country_data = covid_data[["Country_Region", "Province_State", "Active", "Confirmed", "Deaths"]].groupby(["Country_Region", "Province_State"], as_index=False).sum()

# %%
fig = go.Figure()

fig = px.histogram(usa_data, x='Province_State', y='Deaths', title="State wise Deaths in USA")

fig.show()
# Out:
# <div>                            <div id="75d73ffa-bd38-4703-af4c-c70a3cde43e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75d73ffa-bd38-4703-af4c-c70a3cde43e3")) {                    Plotly.newPlot(                        "75d73ffa-bd38-4703-af4c-c70a3cde43e3",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","C ...

# %% [markdown]
# To plot for all the countries:

# %%
fig = px.histogram(all_country_data, x="Country_Region", y="Deaths", color="Province_State", title="Country-wise Deaths")
fig.show()
# Out:
# <div>                            <div id="8f1dfed5-6a57-4173-a554-dc1c34e13043" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f1dfed5-6a57-4173-a554-dc1c34e13043")) {                    Plotly.newPlot(                        "8f1dfed5-6a57-4173-a554-dc1c34e13043",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Australian Capital Territory<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"Australian Capital Territory","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australian Capital Territory","offsetgroup":"Australian Capital Territory","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[3],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=New South Wales<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"New South Wales","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New South Wales","offsetgroup":"New South Wales","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[54],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Northern Territory<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"Northern Territory","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Northern Territory","offsetgroup":"Northern Territory","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[0],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Queensland<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"Queensland","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Queensland","offsetgroup":"Queensland","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[6],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=South Australia<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"South Australia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"South Australia","offsetgroup":"South Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[4],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Tasmania<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"Tasmania","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Tasmania","offsetgroup":"Tasmania","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[13],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Victoria<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"Victoria","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Victoria","offsetgroup":"Victoria","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[820],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Western Australia<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legendgroup":"Western Australia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Western Australia","offsetgroup":"Western Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[9],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Antwerp<br>Country_Region=%{x}<br>sum of Deaths=%{y}<extra></extra>","legend ...

# %% [markdown]
# ### Question 7

# %% [markdown]
# ### Plot Province/State Wise Active Cases in USA

# %%
fig = go.Figure()

fig = px.histogram(usa_data, x='Province_State', y='Active', title="State wise Active Cases in USA")

fig.show()
# Out:
# <div>                            <div id="0b40be35-3b61-4247-a6ae-76c07cab5277" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b40be35-3b61-4247-a6ae-76c07cab5277")) {                    Plotly.newPlot(                        "0b40be35-3b61-4247-a6ae-76c07cab5277",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","C ...

# %%
fig = px.histogram(all_country_data, x="Country_Region", y="Active", color="Province_State", title="Country-wise Active cases")
fig.show()
# Out:
# <div>                            <div id="9c9981bf-e846-4ae2-910e-c321acd854ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c9981bf-e846-4ae2-910e-c321acd854ab")) {                    Plotly.newPlot(                        "9c9981bf-e846-4ae2-910e-c321acd854ab",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Australian Capital Territory<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"Australian Capital Territory","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australian Capital Territory","offsetgroup":"Australian Capital Territory","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[0],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=New South Wales<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"New South Wales","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New South Wales","offsetgroup":"New South Wales","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[4953],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Northern Territory<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"Northern Territory","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Northern Territory","offsetgroup":"Northern Territory","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[19],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Queensland<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"Queensland","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Queensland","offsetgroup":"Queensland","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[27],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=South Australia<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"South Australia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"South Australia","offsetgroup":"South Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[15],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Tasmania<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"Tasmania","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Tasmania","offsetgroup":"Tasmania","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[0],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Victoria<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"Victoria","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Victoria","offsetgroup":"Victoria","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[45],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Western Australia<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","legendgroup":"Western Australia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Western Australia","offsetgroup":"Western Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[15],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Antwerp<br>Country_Region=%{x}<br>sum of Active=%{y}<extra></extra>","le ...

# %% [markdown]
# ### Question 8

# %% [markdown]
# ### Plot Province/State Wise Confirmed cases in USA

# %%
fig = go.Figure()

fig = px.histogram(usa_data, x='Province_State', y='Confirmed', title="State wise Confirmed Cases in USA")

fig.show()
# Out:
# <div>                            <div id="c3226e70-86ef-45d5-b76f-b66650f1a817" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3226e70-86ef-45d5-b76f-b66650f1a817")) {                    Plotly.newPlot(                        "c3226e70-86ef-45d5-b76f-b66650f1a817",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Alaska","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arizona","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","Arkansas","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","California","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado","Colorado" ...

# %%
fig = px.histogram(all_country_data, x="Country_Region", y="Confirmed", color="Province_State", title="Country-wise Confirmed cases")
fig.show()
# Out:
# <div>                            <div id="d1a9cbb9-c84d-4524-b3be-34a356eb0768" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1a9cbb9-c84d-4524-b3be-34a356eb0768")) {                    Plotly.newPlot(                        "d1a9cbb9-c84d-4524-b3be-34a356eb0768",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Australian Capital Territory<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"Australian Capital Territory","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australian Capital Territory","offsetgroup":"Australian Capital Territory","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[118],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=New South Wales<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"New South Wales","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New South Wales","offsetgroup":"New South Wales","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[5007],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Northern Territory<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"Northern Territory","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Northern Territory","offsetgroup":"Northern Territory","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[90],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Queensland<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"Queensland","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Queensland","offsetgroup":"Queensland","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[1274],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=South Australia<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"South Australia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"South Australia","offsetgroup":"South Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[587],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Tasmania<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"Tasmania","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Tasmania","offsetgroup":"Tasmania","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[234],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Victoria<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"Victoria","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Victoria","offsetgroup":"Victoria","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[20410],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Western Australia<br>Country_Region=%{x}<br>sum of Confirmed=%{y}<extra></extra>","legendgroup":"Western Australia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Western Australia","offsetgroup":"Western Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[875],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Province_State=Antwerp<br>Country_Region=%{x}<br>sum ...

# %% [markdown]
# ### Question 9

# %% [markdown]
# ### Plot Worldwide Confirmed Cases over time

# %%
import plotly.express as px
import plotly.io as pio

# %%
covid_data["Last_Update"] = pd.to_datetime(covid_data.Last_Update)

# %%
covid_data["Last_Update"]
# Out:
# 0      2021-01-10 05:22:12
# 1      2021-01-10 05:22:12
# 2      2021-01-10 05:22:12
# 3      2021-01-10 05:22:12
# 4      2021-01-10 05:22:12
#                ...
# 4007   2021-01-10 05:22:12
# 4008   2021-01-10 05:22:12
# 4009   2021-01-10 05:22:12
# 4010   2021-01-10 05:22:12
# 4011   2021-01-10 05:22:12
# Name: Last_Update, Length: 4012, dtype: datetime64[ns]

# %%
fig = px.line(covid_data, x='Last_Update', y="Confirmed", color = "Country_Region", title = "Worldwide Confirmed Cases over time")
fig.show()
# Out:
# <div>                            <div id="0fccc9d4-eed0-42db-9e8c-8ff749b75513" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fccc9d4-eed0-42db-9e8c-8ff749b75513")) {                    Plotly.newPlot(                        "0fccc9d4-eed0-42db-9e8c-8ff749b75513",                        [{"hovertemplate":"Country_Region=Afghanistan<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[53400],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Albania<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Albania","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Albania","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[63033],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Algeria<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Algeria","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[101913],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Andorra<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Andorra","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Andorra","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[8586],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Angola<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Angola","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Angola","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[18156],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Antigua and Barbuda<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Antigua and Barbuda","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Antigua and Barbuda","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[169],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Argentina<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Argentina","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Argentina","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[1714409],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Armenia<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Armenia","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Armenia","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[161794],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Australia<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Australia","showlegend":true,"x":["2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12"],"xaxis":"x","y":[118,5007,90,1274,587,234,20410,875],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country_Region=Austria<br>Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Austria","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Austria","showlegend":true,"x":["2021-01-10T05:22:12"],"xaxis":"x","y":[375239],"yaxis":"y","type": ...
